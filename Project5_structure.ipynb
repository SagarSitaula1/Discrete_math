# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSitaula1/Discrete_math/blob/main/Project5_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part 5 : CPSMA 3133 Dr. Jacob's Discrete Mathematics
#
# ## Structure
#
# ### Sagar Sitaula and 267865

# %% [markdown]
# For the project, I am going to see my daily activities and try to graph in the tree.

# %%
# !pip install anytree
# Out:
# ...
#      |████████████████████████████████| 41 kB 126 kB/s
# ...

# %%
import graphviz

Active = graphviz.Digraph('Dailyactivities')

Active.node('Activities')

Active.edge('Activities','morning')
Active.edge('Activities','afternoon')
Active.edge('Activities','evening')
Active.edge('Activities','night')
Active.edge('Activities','otherTimes')

Active.edge('morning','eat',)
Active.edge('eat','school',)
Active.edge('afternoon','lunch',)
Active.edge('lunch','homework',)
Active.edge('homework','Tv',)
Active.edge('evening','Gym',)
Active.edge('Gym','rest',)
Active.edge('rest','homework',)
Active.edge('night','eat',)
Active.edge('eat','tv',)
Active.edge('tv','sleep',)
Active.edge('otherTimes','tv',)
Active.edge('tv','videogames',)
Active.edge('videogames','rest',)

Active

# %% [markdown]
# for the graph I have created most of the activities done through most of my days during the weekdays. As, on the top the parent node is called activities and under the node activities are five types of nodes which are labeled as morning, afteernoon,evening, night and rest of the day(otherTimes). The morning node has one degree vertices pathed to eat and eat pathed to school. which describes my morning routin to eat breakfast and go schoo, since I have class every morning. Similarly all the different are directed to different activities I do throught out  the day. most of the node has 1 degree vertices but some like tv and eat have 2 degree vertices, because they are connected to two nodes.
# Since, most of my activities are not corelated except for eat and tv my graph doesn't have any cycle.
